# %%
from ecosystem_classes import Foxes
from ecosystem_classes import Run
import pylab
import numpy
fox = Foxes(500, 300, 10000)
run = Run()
run.run_simulation(500, fox)
run.visualisation(fox.rabbits_list, 'go', 'g')
run.visualisation(fox.foxes_list, 'ro', 'r')
pylab.show()
